# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
import os
import yaml
import torch
import logging
from typing import List, Dict, Any

import pandas as pd
from datasets import load_dataset, Dataset
from transformers import pipeline
from tqdm import tqdm
from nltk.tokenize import RegexpTokenizer

import evaluate

class SummarizationEvaluator:
    def __init__(self, config: Dict[str, Any]):
        """Initialize summarization evaluator"""
        self.config = config
        self.logger = self._setup_logger()
        
        # Set up device
        self.device = 0 if torch.cuda.is_available() else -1
        
        # Load evaluation metrics
        self.rouge = evaluate.load('rouge')
        self.bleu = evaluate.load('bleu')
        self.meteor = evaluate.load('meteor')
        self.bertscore = evaluate.load('bertscore')
    
    def _setup_logger(self):
        """Set up logging configuration"""
        logging.basicConfig(
            level=logging.INFO, 
            format='%(asctime)s - %(levelname)s: %(message)s'
        )
        return logging.getLogger(__name__)
    
    def load_dataset(self, subset: bool = False) -> Dataset:
        """Load dataset from configuration"""
        self.logger.info("Loading dataset...")
        dataset = load_dataset(
            self.config['DATASET_PATH'], 
            split="validation"
        )
        
        if subset:
            dataset = Dataset.from_dict(dataset[:10])
        
        return dataset
    
    def load_summarization_pipeline(self, model_path: str) -> Any:
        """Load summarization model pipeline"""
        self.logger.info(f"Loading summarization pipeline: {model_path}")
        tokenizer_path = "tiiuae/Falcon3-1B-Instruct"
        
        model = AutoModelForCausalLM.from_pretrained(
            model_path,
            torch_dtype=torch.bfloat16,
        )
        tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
    
        return pipeline(
            "text-generation", 
            model=model, 
            tokenizer=tokenizer,
            device=self.device,
            torch_dtype=torch.bfloat16,
        )
    
    def generate_summaries(
        self, 
        dataset: Dataset, 
        model_path: str, 
        text_column: str = "text",
        batch_size: int = 16
    ) -> Dataset:
        """Generate summaries in batches"""
        summarizer = self.load_summarization_pipeline(model_path)
        model_name = model_path.split('/')[-1]
        
        input_texts = dataset[text_column]
        summaries = []
        
        is_sft = 'SFT' in model_name or 'Instruct' in model_name
        
        for i in tqdm(range(0, len(input_texts), batch_size), desc=f'Summarizing {model_name}'):
            batch_inputs = input_texts[i:i+batch_size]
            
            # Apply the formatting
            if is_sft:
                formatted_inputs = [
                    f"### System: You are a summarization tool designed exclusively to generate concise summaries of Arabic input text.\n### Human: Summarize the following text in Arabic:\n{source_text}\n### Assistant:" 
                    for source_text in batch_inputs
                ]
            else:
                formatted_inputs = batch_inputs
            
            # Generate summaries
            batch_summaries = summarizer(
                formatted_inputs, 
                do_sample=False, 
                max_new_tokens=128
            )
            
            batch_summaries = [
                summary[0]['generated_text'] for summary in batch_summaries
            ]
            
            summaries.extend(batch_summaries)
        
        dataset = dataset.add_column(f"summary_{model_name}", summaries)
        return dataset

    def compute_metrics(
        self, 
        dataset: Dataset, 
        models: List[str], 
        tokenizer, 
        reference_column: str = "summary"
    ) -> pd.DataFrame:
        """Compute comprehensive metrics with preprocessing"""
        results = []

        for model_path in models:
            model_name = model_path.split('/')[-1]
            summary_column = f"summary_{model_name}"
            
            # Extract predictions and references
            predictions = dataset[summary_column]
            references = dataset[reference_column]

            # Preprocess predictions and references
            predictions = [
                (p if p.endswith(("!", "؟", "۔")) else p + "۔") for p in predictions
            ]
            references = [
                (r if r.endswith(("!", "؟", "۔")) else r + "۔") for r in references
            ]

            sent_tokenizer = RegexpTokenizer(u'[^!؟۔]*[!؟۔]')
            predictions = [
                "\n".join([s.strip() for s in sent_tokenizer.tokenize(p)]) for p in predictions
            ]
            references = [
                "\n".join([s.strip() for s in sent_tokenizer.tokenize(r)]) for r in references
            ]
            
            # Compute ROUGE
            rouge_results = self.rouge.compute(
                predictions=predictions, 
                references=references
            )
            
            # Compute BLEU
            bleu_results = self.bleu.compute(
                predictions=predictions, 
                references=references
            )
            
            # Compute METEOR
            meteor_results = self.meteor.compute(
                predictions=predictions, 
                references=references
            )
            
            # Compute BERTScore
            bertscore_results = self.bertscore.compute(
                predictions=predictions, 
                references=references, 
                lang='ar'
            )
            
            # Aggregate results
            model_metrics = {
                "model": model_name,
                "rouge1": rouge_results["rouge1"] * 100,
                "rouge2": rouge_results["rouge2"] * 100,
                "rougeL": rouge_results["rougeL"] * 100,
                "rougeLsum": rouge_results["rougeLsum"] * 100,
                "bleu": bleu_results["bleu"] * 100,
                "meteor": meteor_results["meteor"] * 100,
                "bertscore_precision": sum(bertscore_results['precision']) / len(bertscore_results['precision']) * 100,
                "bertscore_recall": sum(bertscore_results['recall']) / len(bertscore_results['recall']) * 100,
                "bertscore_f1": sum(bertscore_results['f1']) / len(bertscore_results['f1']) * 100
            }
            
            results.append(model_metrics)
        
        return pd.DataFrame(results)

    
    def compute_metrics(
        self, 
        dataset: Dataset, 
        models: List[str], 
        reference_column: str = "summary"
    ) -> pd.DataFrame:
        """Compute comprehensive metrics"""
        results = []
        
        for model_path in models:
            model_name = model_path.split('/')[-1]
            summary_column = f"summary_{model_name}"
            
            # Extract predictions and references
            predictions = dataset[summary_column]
            references = dataset[reference_column]
            
            # Compute ROUGE
            rouge_results = self.rouge.compute(
                predictions=predictions, 
                references=references
            )
            
            # Compute BLEU
            bleu_results = self.bleu.compute(
                predictions=predictions, 
                references=references
            )
            
            # # Compute METEOR
            # meteor_results = self.meteor.compute(
            #     predictions=predictions, 
            #     references=references
            # )
            
            # Compute BERTScore
            # bertscore_results = self.bertscore.compute(
            #     predictions=predictions, 
            #     references=references, 
            #     lang='ar'
            # )
            
            # Aggregate results
            model_metrics = {
                "model": model_name,
                "rouge1": rouge_results["rouge1"] * 100,
                "rouge2": rouge_results["rouge2"] * 100,
                "rougeL": rouge_results["rougeL"] * 100,
                "rougeLsum": rouge_results["rougeLsum"] * 100,
                "bleu": bleu_results["bleu"] * 100,
                # "meteor": meteor_results["meteor"] * 100,
                # "bertscore_precision": sum(bertscore_results['precision']) / len(bertscore_results['precision']) * 100,
                # "bertscore_recall": sum(bertscore_results['recall']) / len(bertscore_results['recall']) * 100,
                # "bertscore_f1": sum(bertscore_results['f1']) / len(bertscore_results['f1']) * 100
            }
            
            results.append(model_metrics)
        
        return pd.DataFrame(results)
    
    def save_results(
        self, 
        dataset: Dataset, 
        metrics_df: pd.DataFrame, 
        output_path: str
    ):
        """Save results to disk"""
        os.makedirs(output_path, exist_ok=True)
        
        self.logger.info(f"Saving results to {output_path}...")
        
        dataset_df = dataset.to_pandas()
        dataset_df.to_csv(os.path.join(output_path, "summarized_dataset.csv"), index=False)
        metrics_df.to_csv(os.path.join(output_path, "metrics.csv"), index=False)
    
    def run_evaluation(self, subset: bool = False):
        """Run complete evaluation pipeline"""
        dataset = self.load_dataset(subset)
        
        for model_path in self.config['EVALUATE_MODELS']:
            dataset = self.generate_summaries(
                dataset, 
                model_path, 
                text_column=self.config['TEXT_COLUMN']
            )
            
            # Free GPU memory after each model evaluation as we do not need the model to stay in VRAM
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
        
        metrics_df = self.compute_metrics(
            dataset, 
            self.config['EVALUATE_MODELS']
        )
        
        self.save_results(
            dataset, 
            metrics_df, 
            self.config.get('OUTPUT_PATH', './results')
        )
        
        return dataset, metrics_df

# %%
df = pd.read_csv("summarized_dataset.csv")

# %%
df
# Out:
#                                                   text  \
# 0    يوجد الكثير من الأساليب التي تتعدى ممارسة الجن...
# 1    لقد ظهر أن التمارين الفترية عالية الشدة (HIIT)...
# 2    عبد الحكيم حذاقة-الجزائر عاشت الجزائر مرحلة مف...
# 3    يحتاج صديقك في أغلب الأوقات لعناق كبير يطمئنه ...
# 4    إن كان الطبيب أو الأخصائي يعتقد بأن رقبتك مستق...
# ..                                                 ...
# 432  حدد ماهية المشكلة قبل القيام بإعادة تثبيت كامل...
# 433  الذهاب مبكرا جدا إلى المستشفى قد يؤدي إلى تدخل...
# 434  قبل الصعود على مركب (كبيرا كان أم صغيرا) حاول ...
# 435  لكل شخص حق في الحصول على وتقبل المساعدة، كما أ...
# 436  قبل عمل أي تغييرات ملحوظة في نظام غذائك، حتى و...
#
#                                                summary  \
# 0    في العلاقات السليمة، يمكنك بناء الثقة والتقارب...
# 1    تساعد التمارين الفترية عالية الشدة على فقدان ا...
# 2    شهدت الجزائر خلال أكتوبر-ديسمبر 2019 ثورة سلمي...
# 3    تتضمن النصائح تقديم العناق والمس، الاستماع، تق...
# 4    في حالة استقرار الرقبة، يمكن بدء العلاج الطبيع...
# ..                                                 ...
# 432  للحل قبل إعادة تثبيت نظام Windows بشكل كامل:\n...
# 433  الذهاب مبكرا للمستشفى قد يؤدي لتدخلات غير ضرور...
# 434  قبل الإبحار، تجنب الأطعمة الثقيلة والدهنية وال...
# 435  حق الشخص في الحصول والرفض للمساعدة، مع إمكانية...
# 436  قبل إجراء تغييرات في نظامك الغذائي، استشر طبيب...
#
#                summary_model_name                tokenizer_name  \
# 0    Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 1    Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 2    Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 3    Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 4    Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# ..                            ...                           ...
# 432  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 433  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 434  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 435  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 436  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
#
#                                dataset_source  sequence_length  \
# 0    Abdelkareem/wikihow-arabic-summarization              969
# 1    Abdelkareem/wikihow-arabic-summarization             1171
# 2    Abdelkareem/arabic-article-summarization             1887
# 3    Abdelkareem/wikihow-arabic-summarization             2439
# 4    Abdelkareem/wikihow-arabic-summarization             1587
# ..                                        ...              ...
# 432  Abdelkareem/wikihow-arabic-summarization             1552
# 433  Abdelkareem/wikihow-arabic-summarization             1125
# 434  Abdelkareem/wikihow-arabic-summarization             1465
# 435  Abdelkareem/wikihow-arabic-summarization             1281
# 436  Abdelkareem/wikihow-arabic-summarization             1323
#
#     summary_Qwen2.5-0.5B-Instruct-bs-2-lr-2e-05-ep-1-wp-100-gacc-32-gnm-1.0-FP16-SFT-mx-2048-v2
# 0    في العلاقات السليمة، يمكن استخدام الأنشطة المخ...
# 1    تشير النصوص إلى أهمية التمارين الرياضية الفتري...
# 2           شهدت الجزائر ثورة سلمية في عام 2019، لكنها
# 3    ### System: You are a summarization tool desig...
# 4     في بداية الجلسة، تطلب الأخصائي تغيير رقبتك لتشمل
# ..                                                 ...
# 432  في إعادة تثبيت Windows 7، قم بتحديد المشكلة وا...
# 433  تشير النصوص إلى أهمية الذهاب مبكرا إلى المستشف...
# 434  قبل الصعود على مركبة البحرية، يجب الحرص على تج...
# 435  لكل شخص حق في الحصول على وتقدير المساعدة، ويمك...
# 436  يجب مراجعة طبيبك قبل تغيير النظام الغذائي. يجب...
#
# [437 rows x 7 columns]

# %%
df[df["sequence_length"] <1024]
# Out:
#                                                   text  \
# 0    يوجد الكثير من الأساليب التي تتعدى ممارسة الجن...
# 5    عندما يفقد الجسم الحرارة أسرع مما يكتسبها يكون...
# 7    يمكنك الحصول على قصة الشعر التي تعجبك من خلال ...
# 10   \nدعا النائب بمجلس نواب الشعب وليد جلاّد رئيسة...
# 14   البورسلين معرض للخدش بسهولة، لذا تجنب استخدام ...
# ..                                                 ...
# 422  دعا الرئيس الفرنسي إيمانويل ماكرون الأوروبيين ...
# 425  \nتنقل الرادار اليوم الأربعاء 11 جانفي 2017 إل...
# 428  هذا الفخ الشائع والزهيد متاح في معظم متاجر الع...
# 430  \nتداول رواد مواقع التواصل الاجتماعي صوراً لشا...
# 431  افركي قطرة خل أبيض على السطح المغيم بإصبعك. ست...
#
#                                                summary  \
# 0    في العلاقات السليمة، يمكنك بناء الثقة والتقارب...
# 5    عند انخفاض درجة حرارة الجسم عن 35 درجة مئوية، ...
# 7    يمكنك الحصول على قصة الشعر التي تعجبك من خلال ...
# 10   دعا النائب وليد جلاّد رئيسة هيئة الحقيقة و الك...
# 14   تجنب استخدام لوفات التنظيف على البورسلين واستخ...
# ..                                                 ...
# 422  دعا ماكرون الأوروبيين إلى تحرك فعال في مواجهة ...
# 425  تنقل رادار الفحص الفني للسيارات في سوسa إلى مر...
# 428  فخ غراء لصيد الثعابين يتضمن صندوق الغراء وطعام...
# 430  شاركت أشخاص على الإنترنت في الترويج لشاب إيران...
# 431  افركي قطرة خل أبيض على السطح المغيم. إذا بقي م...
#
#                summary_model_name                tokenizer_name  \
# 0    Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 5    Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 7    Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 10   Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 14   Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# ..                            ...                           ...
# 422  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 425  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 428  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 430  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
# 431  Qwen/Qwen2.5-7B-Instruct-AWQ  Qwen/Qwen2.5-7B-Instruct-AWQ
#
#                                       dataset_source  sequence_length  \
# 0           Abdelkareem/wikihow-arabic-summarization              969
# 5           Abdelkareem/wikihow-arabic-summarization              679
# 7           Abdelkareem/wikihow-arabic-summarization              741
# 10   Abdelkareem/Arabic-article-summarization-30-000              302
# 14          Abdelkareem/wikihow-arabic-summarization              740
# ..                                               ...              ...
# 422         Abdelkareem/arabic-article-summarization              636
# 425  Abdelkareem/Arabic-article-summarization-30-000              249
# 428         Abdelkareem/wikihow-arabic-summarization              427
# 430  Abdelkareem/Arabic-article-summarization-30-000              296
# 431         Abdelkareem/wikihow-arabic-summarization              715
#
#     summary_Qwen2.5-0.5B-Instruct-bs-2-lr-2e-05-ep-1-wp-100-gacc-32-gnm-1.0-FP16-SFT-mx-2048-v2
# 0    في العلاقات السليمة، يمكن استخدام الأنشطة المخ...
# 5    إن انخفاض حرارة الجسم يؤدي إلى مشاكل صحية خطير...
# 7    يمكن الوصول إلى قصة الشعر الخاصة بك من خلال تو...
# 10   دعا النائب جلاًد رئيسة هيئة الحقيقة و الكرامة ...
# 14           بروسبين معرض للخدش، استخدم إسفنجة نظيفة و
# ..                                                 ...
# 422  دعا الرئيس الفرنسي إيمانويل ماكرون الأوروبيين ...
# 425  تتواصل الرادار مع مركز الفحص الفني لنقل السيار...
# 428  الفخ الشائع والمفيد هو صندوق يمكن وضعه تحت الغ...
# 430       طلب رضا برستش لزيارة ميسي بسبب تطابق وجهه مع
# 431     افركي قطرة خل أبيض على السطح المغيم وإيقاف الع
#
# [181 rows x 7 columns]

# %%
df["summary_Qwen2.5-0.5B-Instruct-bs-2-lr-2e-05-ep-1-wp-100-gacc-32-gnm-1.0-FP16-SFT-mx-2048-v2"].iloc[2]
# Out:
# 'شهدت الجزائر ثورة سلمية في عام 2019، لكنها'

# %%
"Assistant" in df["summary_Qwen2.5-0.5B-Instruct-bs-2-lr-2e-05-ep-1-wp-100-gacc-32-gnm-1.0-FP16-SFT-mx-2048-v2"].iloc[80]
# Out:
# False

# %%
df["summary_Qwen2.5-0.5B-Instruct-bs-2-lr-2e-05-ep-1-wp-100-gacc-32-gnm-1.0-FP16-SFT-mx-2048-v2"].iloc[0]

# %%
with open('eval_config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %%
evaluator = SummarizationEvaluator(config)
dataset, metrics = evaluator.run_evaluation(subset=False)

print("Model Performance Metrics:")
print(metrics)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/infres/abounhar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/infres/abounhar/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/infres/abounhar/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 2025-01-26 23:09:56,251 - INFO: Loading dataset...
# 2025-01-26 23:09:58,722 - INFO: Loading summarization pipeline: BounharAbdelaziz/Falcon3-1B-Base-bs-2-lr-2e-05-ep-3-wp-100-gacc-32-gnm-1.0-FP16-mx-2048-lora-r-128-a-32
# Device set to use cuda:0
# Summarizing Falcon3-1B-Base-bs-2-lr-2e-05-ep-3-wp-100-gacc-32-gnm-1.0-FP16-mx-2048-lora-r-128-a-32:   0%|          | 0/28 [00:00<?, ?it/s]This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (4096). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# Summarizing Falcon3-1B-Base-bs-2-lr-2e-05-ep-3-wp-100-gacc-32-gnm-1.0-FP16-mx-2048-lora-r-128-a-32:  36%|███▌      | 10/28 [06:20<11:23, 37.98s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Summarizing Falcon3-1B-Base-bs-2-lr-2e-05-ep-3-wp-100-gacc-32-gnm-1.0-FP16-mx-2048-lora-r-128-a-32: 100%|██████████| 28/28 [16:04<00:00, 34.45s/it]
# 2025-01-26 23:26:07,074 - INFO: Using default tokenizer.
# 2025-01-26 23:26:08,512 - INFO: Saving results to metrics.csv...
# Model Performance Metrics:
#                                                model     rouge1    rouge2  \
# 0  Falcon3-1B-Base-bs-2-lr-2e-05-ep-3-wp-100-gacc...  10.534322  4.505363
#
#       rougeL  rougeLsum      bleu
# 0  10.468481  10.428355  1.578146

# %%
dataset
# Out:
# Dataset({
#     features: ['text', 'summary', 'summary_model_name', 'tokenizer_name', 'dataset_source', 'sequence_length', 'summary_Falcon3-1B-Base-bs-2-lr-2e-05-ep-3-wp-100-gacc-32-gnm-1.0-FP16-mx-2048-lora-r-128-a-32'],
#     num_rows: 437
# })

# %%
dataset[0]
# Out:
# {'text': 'يوجد الكثير من الأساليب التي تتعدى ممارسة الجنس لتكوني قريبة من الطرف الآخر في العلاقات السليمة. يمكنك بناء الثقة والتقارب في العلاقة من خلال التحدث والاستماع والمشاركة واحترام أفكاركما ومن خلال الخروج معا والاستمتاع بصحبة بعضكما البعض. إذا حاول شريكك إخبارك بأن الجنس هو الطريقة الوحيدة التي يمكنكما التقارب بها، فقد تحتاجين إلى التفكير فيما إذا كانت هذه العلاقة هي ما تريدينه حقا. من الممتع أن تجلسي مع شريكك وتقوما بنشاطات غير جنسية. يعد اللعب بألعاب لوحية وسيلة رائعة لإراحة شريكك وتخفيف توتره دون الحاجة لممارسة الجنس. اجلسا بجانب بعضكما البعض واستندا على بعض الوسائد وتناوبا على القراءة. يمكنكما حتى اختيار الكتب بالتناوب. يعتمد قرب جلوسكما على درجة راحتك.  إذا كنت قلقة بشأن تطور الأمور، فحاولي أن تبتعدي قليلا. يمكنك الجلوس مثلا على طرف مقابل له مع تلامس قدميكما فقط. يمكنكما قراءة بعض القصص الرومانسية لبعضكما من أجل تشتيت الانتباه بعيدا عن الجنس (وربما كي تضحكا على مدى رداءة القصص). اجلسا معا واستمعا إلى ألبوم. ابحثي عن كلمات الأغاني واجلسي بالقرب من شريكك وتمتعي بقرب جسدكما. ولكن لا تفعلا أكثر من مشابكة أياديكما أو احتضان بعضكما. اكتبا استطلاعات رأي لبعضكما البعض أو اطبعا بعضا منها مسبقا من الإنترنت (ابحثا عن "أسئلة ممتعة لشريكك"). اجلسا على جانبين متقابلين وليجب كل منكما بالإجابة على استبيانه وحده، ثم تبادلا الاستبيانين بمجرد الانتهاء لقراءة الردود. حضرا بعض الوجبات الخفيفة والكثير من الوسائد لمشاهدة فيلم ما. إذا كنت قلقة من تحول الفيلم إلى جلسة حميمية، ضعي الوسائد بينك وبينه واستخدما بطانيتين منفصلتين. إذا لم تؤدي الوسائد والبطانيتين وظيفتهما، فلا بأس من سؤال شريكك إذا كان ينوي فعل شيء آخر يستدعي مقاومتك. حولي المكان الذي ستجلسان فيه إلى حصن. أضيفي بعض الأضواء والبطانيات الأنيقة ثم اجلسا في داخله وشاهدا فيلما أو اقرآ بعض القصص. قد يؤدي جلوسك بالقرب من شريكك إلى صعوبة في مقاومة تطور الأمر لأكثر من مجرد احتضان. إذا وجدت نفسك تفكرين في تجاوز حدودكما المحددة مسبقا، ابتعدي عن شريكك أو اقترحي الجلوس في مكان آخر.  إذا كنت قلقة من الإساءة إلى شريكك بابتعادك عنه، فيمكنك التذرع لرغبتك في الانتقال على سبيل المثال بحجة مثل: "ظهري يؤلمني من الجلوس هنا، دعنا نجلس على أريكة أخرى" أو "أشعر ببعض الضيق، لنأخذ استراحة ونذهب للمشي!" سوف يساعدك الخروج إلى الأماكن العامة على كبح رغباتك الجنسية. إذا تطورت بينكما الأمور لوضع مثير وشعرت بالسوء حيال الأمر، لا بأس في التوقف وقول إنك لا تشعرين بالراحة في الاستمرار. يجب أن يحترم شريكك رغباتك على الفور.  إذا حاول شريكك إقناعك بتجاوز الحدود التي وضعتها بشكل متكرر، فقد تحتاجين إلى التفكير في استمرار علاقتك معه. على الرغم من أنه من المقبول أن يسألك شريكك عن رأيك مرة أخرى بين الحين والآخر، إلا أنه لا ينبغي أن يشعرك بالسوء نحو قرارك.',
#  'summary': 'في العلاقات السليمة، يمكنك بناء الثقة والتقارب من خلال التحدث والاستماع والمشاركة واحترام أفكاركما. يمكن استخدام نشاطات غير جنسية مثل اللعب بألعاب لوحية أو القراءة معا. يمكنك أيضا إجراء استطلاعات رأي أو مشاهدة فيلم مع وسائد وأضواء. إذا شعرت بالقلق، ابتعدي قليلا أو تقدمي لسببًا لنقل المكان. يجب أن يحترم شريكك رغباتك ويشعرك بالراحة.',
#  'summary_model_name': 'Qwen/Qwen2.5-7B-Instruct-AWQ',
#  'tokenizer_name': 'Qwen/Qwen2.5-7B-Instruct-AWQ',
#  'dataset_source': 'Abdelkareem/wikihow-arabic-summarization',
#  'sequence_length': 969,
#  'summary_Falcon3-1B-Base-bs-2-lr-2e-05-ep-3-wp-100-gacc-32-gnm-1.0-FP16-mx-2048-lora-r-128-a-32': 'يوجد الكثير من الأساليب التي تتعدى ممارسة الجنس لتكوني قريبة من الطرف الآخر في العلاقات السليمة. يمكنك بناء الثقة والتقارب في العلاقة من خلال التحدث والاستماع والمشاركة واحترام أفكاركما ومن خلال الخروج معا والاستمتاع بصحبة بعضكما البعض. إذا حاول شريكك إخبارك بأن الجنس هو الطريقة الوحيدة التي يمكنكما التقارب بها، فقد تحتاجين إلى التفكير فيما إذا كانت هذه العلاقة هي ما تريدينه حقا. من الممتع أن تجلسي مع شريكك وتقوما بنشاطات غير جنسية. يعد اللعب بألعاب لوحية وسيلة رائعة لإراحة شريكك وتخفيف توتره دون الحاجة لممارسة الجنس. اجلسا بجانب بعضكما البعض واستندا على بعض الوسائد وتناوبا على القراءة. يمكنكما حتى اختيار الكتب بالتناوب. يعتمد قرب جلوسكما على درجة راحتك.  إذا كنت قلقة بشأن تطور الأمور، فحاولي أن تبتعدي قليلا. يمكنك الجلوس مثلا على طرف مقابل له مع تلامس قدميكما فقط. يمكنكما قراءة بعض القصص الرومانسية لبعضكما من أجل تشتيت الانتباه بعيدا عن الجنس (وربما كي تضحكا على مدى رداءة القصص). اجلسا معا واستمعا إلى ألبوم. ابحثي عن كلمات الأغاني واجلسي بالقرب من شريكك وتمتعي بقرب جسدكما. ولكن لا تفعلا أكثر من مشابكة أياديكما أو احتضان بعضكما. اكتبا استطلاعات رأي لبعضكما البعض أو اطبعا بعضا منها مسبقا من الإنترنت (ابحثا عن "أسئلة ممتعة لشريكك"). اجلسا على جانبين متقابلين وليجب كل منكما بالإجابة على استبيانه وحده، ثم تبادلا الاستبيانين بمجرد الانتهاء لقراءة الردود. حضرا بعض الوجبات الخفيفة والكثير من الوسائد لمشاهدة فيلم ما. إذا كنت قلقة من تحول الفيلم إلى جلسة حميمية، ضعي الوسائد بينك وبينه واستخدما بطانيتين منفصلتين. إذا لم تؤدي الوسائد والبطانيتين وظيفتهما، فلا بأس من سؤال شريكك إذا كان ينوي فعل شيء آخر يستدعي مقاومتك. حولي المكان الذي ستجلسان فيه إلى حصن. أضيفي بعض الأضواء والبطانيات الأنيقة ثم اجلسا في داخله وشاهدا فيلما أو اقرآ بعض القصص. قد يؤدي جلوسك بالقرب من شريكك إلى صعوبة في مقاومة تطور الأمر لأكثر من مجرد احتضان. إذا وجدت نفسك تفكرين في تجاوز حدودكما المحددة مسبقا، ابتعدي عن شريكك أو اقترحي الجلوس في مكان آخر.  إذا كنت قلقة من الإساءة إلى شريكك بابتعادك عنه، فيمكنك التذرع لرغبتك في الانتقال على سبيل المثال بحجة مثل: "ظهري يؤلمني من الجلوس هنا، دعنا نجلس على أريكة أخرى" أو "أشعر ببعض الضيق، لنأخذ استراحة ونذهب للمشي!" سوف يساعدك الخروج إلى الأماكن العامة على كبح رغباتك الجنسية. إذا تطورت بينكما الأمور لوضع مثير وشعرت بالسوء حيال الأمر، لا بأس في التوقف وقول إنك لا تشعرين بالراحة في الاستمرار. يجب أن يحترم شريكك رغباتك على الفور.  إذا حاول شريكك إقناعك بتجاوز الحدود التي وضعتها بشكل متكرر، فقد تحتاجين إلى التفكير في استمرار علاقتك معه. على الرغم من أنه من المقبول أن يسألك شريكك عن رأيك مرة أخرى بين الحين والآخر، إلا أنه لا ينبغي أن يشعرك بالسوء نحو قرارك.  إذا كنت قلقة من الإساءة إلى شريكك بابتعادك عنه، فيمكنك التذرع لرغبتك في الانتقال على سبيل المثال بحجة مثل: "ظهري يؤلمني من الجلوس هنا، دعنا نجلس على أريك'}

# %%
metrics
# Out:
#                                                model     rouge1    rouge2  \
# 0  Falcon3-1B-Base-bs-2-lr-2e-05-ep-3-wp-100-gacc...  10.534322  4.505363
#
#       rougeL  rougeLsum      bleu
# 0  10.468481  10.428355  1.578146

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, DataCollatorForLanguageModeling
import torch
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
def load_model_and_tokenizer(path):
    model = AutoModelForCausalLM.from_pretrained(
        path,
        torch_dtype=torch.bfloat16,
    ).to("cuda")

    model.eval()

    tokenizer = AutoTokenizer.from_pretrained(path)
    
    return model, tokenizer

# %%
model_path = "BounharAbdelaziz/Qwen2.5-0.5B-Instruct-bs-2-lr-1e-05-ep-1-wp-100-gacc-32-gnm-1.0-FP16-SFT-mx-2048-v2"
model, tokenizer = load_model_and_tokenizer(model_path)
model_name = model_path.split('/')[-1]
max_length = 2048
max_new_tokens = 2048

# %%
dataset = load_dataset("BounharAbdelaziz/Arabic-Synthetic-Summarization-Dataset-Filtered", split="test")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 dataset = load_dataset("BounharAbdelaziz/Arabic-Synthetic-Summarization-Dataset-Filtered", split="test")
#
# NameError: name 'load_dataset' is not defined

# %%
test_input = """يوجد الكثير من الأساليب التي تتعدى ممارسة الجنس لتكوني قريبة من الطرف الآخر في العلاقات السليمة. يمكنك بناء الثقة والتقارب في العلاقة من خلال التحدث والاستماع والمشاركة واحترام أفكاركما ومن خلال الخروج معا والاستمتاع بصحبة بعضكما البعض. إذا حاول شريكك إخبارك بأن الجنس هو الطريقة الوحيدة التي يمكنكما التقارب بها، فقد تحتاجين إلى التفكير فيما إذا كانت هذه العلاقة هي ما تريدينه حقا. من الممتع أن تجلسي مع شريكك وتقوما بنشاطات غير جنسية. يعد اللعب بألعاب لوحية وسيلة رائعة لإراحة شريكك وتخفيف توتره دون الحاجة لممارسة الجنس. اجلسا بجانب بعضكما البعض واستندا على بعض الوسائد وتناوبا على القراءة. يمكنكما حتى اختيار الكتب بالتناوب. يعتمد قرب جلوسكما على درجة راحتك. إذا كنت قلقة بشأن تطور الأمور، فحاولي أن تبتعدي قليلا. يمكنك الجلوس مثلا على طرف مقابل له مع تلامس قدميكما فقط. يمكنكما قراءة بعض القصص الرومانسية لبعضكما من أجل تشتيت الانتباه بعيدا عن الجنس (وربما كي تضحكا على مدى رداءة القصص). اجلسا معا واستمعا إلى ألبوم. ابحثي عن كلمات الأغاني واجلسي بالقرب من شريكك وتمتعي بقرب جسدكما. ولكن لا تفعلا أكثر من مشابكة أياديكما أو احتضان بعضكما. اكتبا استطلاعات رأي لبعضكما البعض أو اطبعا بعضا منها مسبقا من الإنترنت (ابحثا عن "أسئلة ممتعة لشريكك"). اجلسا على جانبين متقابلين وليجب كل منكما بالإجابة على استبيانه وحده، ثم تبادلا الاستبيانين بمجرد الانتهاء لقراءة الردود. حضرا بعض الوجبات الخفيفة والكثير من الوسائد لمشاهدة فيلم ما. إذا كنت قلقة من تحول الفيلم إلى جلسة حميمية، ضعي الوسائد بينك وبينه واستخدما بطانيتين منفصلتين. إذا لم تؤدي الوسائد والبطانيتين وظيفتهما، فلا بأس من سؤال شريكك إذا كان ينوي فعل شيء آخر يستدعي مقاومتك. حولي المكان الذي ستجلسان فيه إلى حصن. أضيفي بعض الأضواء والبطانيات الأنيقة ثم اجلسا في داخله وشاهدا فيلما أو اقرآ بعض القصص. قد يؤدي جلوسك بالقرب من شريكك إلى صعوبة في مقاومة تطور الأمر لأكثر من مجرد احتضان. إذا وجدت نفسك تفكرين في تجاوز حدودكما المحددة مسبقا، ابتعدي عن شريكك أو اقترحي الجلوس في مكان آخر. إذا كنت قلقة من الإساءة إلى شريكك بابتعادك عنه، فيمكنك التذرع لرغبتك في الانتقال على سبيل المثال بحجة مثل: "ظهري يؤلمني من الجلوس هنا، دعنا نجلس على أريكة أخرى" أو "أشعر ببعض الضيق، لنأخذ استراحة ونذهب للمشي!" سوف يساعدك الخروج إلى الأماكن العامة على كبح رغباتك الجنسية. إذا تطورت بينكما الأمور لوضع مثير وشعرت بالسوء حيال الأمر، لا بأس في التوقف وقول إنك لا تشعرين بالراحة في الاستمرار. يجب أن يحترم شريكك رغباتك على الفور. إذا حاول شريكك إقناعك بتجاوز الحدود التي وضعتها بشكل متكرر، فقد تحتاجين إلى التفكير في استمرار علاقتك معه. على الرغم من أنه من المقبول أن يسألك شريكك عن رأيك مرة أخرى بين الحين والآخر، إلا أنه لا ينبغي أن يشعرك بالسوء نحو قرارك."""

def predict_summary(test_input, model, tokenizer, max_length, max_new_tokens, model_name):

    # custom instruct prompt start
    prompt_template_test = f"Summarize this arabic text:\n{{text}}\n---\nSummary:\n"

    test_prompt = prompt_template_test.format(text=test_input)
    print(test_prompt)
    
    # Tokenize and generate
    inputs = tokenizer(test_prompt, return_tensors="pt", max_length=max_length).to("cuda")
    outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            # num_beams=4,
            # early_stopping=True,
            # no_repeat_ngram_size=3,
            # repetition_penalty=1.2,
            eos_token_id=tokenizer.eos_token_id,  # Crucial for stopping
            # pad_token_id=tokenizer.eos_token_id,  # Crucial for stopping
            # do_sample=True,
        )


    # Decode the output
    summary = tokenizer.decode(outputs[0], skip_special_tokens=True)
    cleaned_summary = summary.split("Summary:")[-1].strip()
    # print('-'*100)
    # print(f"{summary}")
    # print('-'*100)
    # print(f"{cleaned_summary}")
    
    return {f"summary_{model_name}": cleaned_summary}

# %%
_ = predict_summary(test_input, model, tokenizer, max_length, max_new_tokens, model_name)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Summarize this arabic text:
# يوجد الكثير من الأساليب التي تتعدى ممارسة الجنس لتكوني قريبة من الطرف الآخر في العلاقات السليمة. يمكنك بناء الثقة والتقارب في العلاقة من خلال التحدث والاستماع والمشاركة واحترام أفكاركما ومن خلال الخروج معا والاستمتاع بصحبة بعضكما البعض. إذا حاول شريكك إخبارك بأن الجنس هو الطريقة الوحيدة التي يمكنكما التقارب بها، فقد تحتاجين إلى التفكير فيما إذا كانت هذه العلاقة هي ما تريدينه حقا. من الممتع أن تجلسي مع شريكك وتقوما بنشاطات غير جنسية. يعد اللعب بألعاب لوحية وسيلة رائعة لإراحة شريكك وتخفيف توتره دون الحاجة لممارسة الجنس. اجلسا بجانب بعضكما البعض واستندا على بعض الوسائد وتناوبا على القراءة. يمكنكما حتى اختيار الكتب بالتناوب. يعتمد قرب جلوسكما على درجة راحتك. إذا كنت قلقة بشأن تطور الأمور، فحاولي أن تبتعدي قليلا. يمكنك الجلوس مثلا على طرف مقابل له مع تلامس قدميكما فقط. يمكنكما قراءة بعض القصص الرومانسية لبعضكما من أجل تشتيت الانتباه بعيدا عن الجنس (وربما كي تضحكا على مدى رداءة القصص). اجلسا معا واستمعا إلى ألبوم. ابحثي عن كلمات الأغاني واجلسي بالقرب من شريكك وتمتعي بقرب جسدكما. ولكن لا تفعلا أكثر من مشابكة أياديكما أو احتضان بعضكما. اكتبا استطلاعات رأي لبعضكما البعض أو اطبعا بعضا منها مسبقا من الإنترنت (ابحثا عن "أسئلة ممتعة لشريكك"). اجلسا على جانبين متقابلين وليجب كل منكما بالإجابة على استبيانه وحده، ثم تبادلا الاستبيانين بمجرد الانتهاء لقراءة الردود. حضرا بعض الوجبات الخفيفة والكثير من الوسائد لمشاهدة فيلم ما. إذا كنت قلقة من تحول الفيلم إلى جلسة حميمية، ضعي الوسائد بينك وبينه واستخدما بطانيتين منفصلتين. إذا لم تؤدي الوسائد والبطانيتين وظيفتهما، فلا بأس من سؤال شريكك إذا كان ينوي فعل شيء آخر يستدعي مقاومتك. حولي المكان الذي ستجلسان فيه إلى حصن. أضيفي بعض الأضواء والبطانيات الأنيقة ثم اجلسا في داخله وشاهدا فيلما أو اقرآ بعض القصص. قد يؤدي جلوسك بالقرب من شريكك إلى صعوبة في مقاومة تطور الأمر لأكثر من مجرد احتضان. إذا وجدت نفسك تفكرين في تجاوز حدودكما المحددة مسبقا، ابتعدي عن شريكك أو اقترحي الجلوس في مكان آخر. إذا كنت قلقة من الإساءة إلى شريكك بابتعادك عنه، فيمكنك التذرع لرغبتك في الانتقال على سبيل المثال بحجة مثل: "ظهري يؤلمني من الجلوس هنا، دعنا نجلس على أريكة أخرى" أو "أشعر ببعض الضيق، لنأخذ استراحة ونذهب للمشي!" سوف يساعدك الخروج إلى الأماكن العامة على كبح رغباتك الجنسية. إذا تطورت بينكما الأمور لوضع مثير وشعرت بالسوء حيال الأمر، لا بأس في التوقف وقول إنك لا تشعرين بالراحة في الاستمرار. يجب أن يحترم شريكك رغباتك على الفور. إذا حاول شريكك إقناعك بتجاوز الحدود التي وضعتها بشكل متكرر، فقد تحتاجين إلى التفكير في استمرار علاقتك معه. على الرغم من أنه من المقبول أن يسألك شريكك عن رأيك مرة أخرى بين الحين والآخر، إلا أنه لا ينبغي أن يشعرك بالسوء نحو قرارك.
# ---
# Summary:

# %%
_
# Out:
# {'summary_Qwen2.5-0.5B-Instruct-bs-2-lr-1e-05-ep-1-wp-100-gacc-32-gnm-1.0-FP16-SFT-mx-2048-v2': 'يتم بناء الثقة والتقارب في العلاقات السليمة من خلال التواصل والمشاركة وإظهار الأهمية للحب. يمكن استخدام الألعاب لوحية، الكتابات الرومانسية، النشاطات الرياضية، ووسائل التواصل الاجتماعي لزيادة الشعور بالراحة. إذا كانت العلاقة ليست رياضية، يمكنك استخدام الوسائل الأخرى لتشتت الانتباه.'}

# %%
import re
from nltk.tokenize import RegexpTokenizer

# Post-process text for ROUGE and BLEU
# def postprocess_text(texts):
#     # Remove punctuation using regex
#     texts = [re.sub(r'[^\w\s]', '', t) for t in texts]
    
#     # # Tokenize into sentences using RegexpTokenizer
#     # sent_tokenizer = RegexpTokenizer(r'\w+')
#     # texts = [" ".join(sent_tokenizer.tokenize(t)) for t in texts]
#     return texts

# Post-process text for ROUGE and BLEU
def postprocess_text(texts):
    text_preds = [(p if p.endswith(("!", "؟", "۔")) else p + "۔") for p in texts]

    sent_tokenizer = RegexpTokenizer(u'[^!؟۔]*[!؟۔]')
    text_preds = ["\n".join([s.strip() for s in sent_tokenizer.tokenize(p)]) for p in text_preds]
    return text_preds

# %%
s = summary.split("Summary:")[-1]
print(s)
s = postprocess_text(s)
print(s)
# Out:
# يوجد العديد من الطرق للتعامل مع العلاقة بين الشريكين، بما في ذلك استخدام الثقة والتواصل والمشاركة، كما يمكن استخدام الألعاب للفيديو والكتب والأنشطة الرياضية لزيادة التنوع. يجب أن يكون لديك اتصال مباشر ومباشر مع شريكك حتى تتمكن من التوصل إليه.
# ['۔', 'ي۔', 'و۔', 'ج۔', 'د۔', '۔', 'ا۔', 'ل۔', 'ع۔', 'د۔', 'ي۔', 'د۔', '۔', 'م۔', 'ن۔', '۔', 'ا۔', 'ل۔', 'ط۔', 'ر۔', 'ق۔', '۔', 'ل۔', 'ل۔', 'ت۔', 'ع۔', 'ا۔', 'م۔', 'ل۔', '۔', 'م۔', 'ع۔', '۔', 'ا۔', 'ل۔', 'ع۔', 'ل۔', 'ا۔', 'ق۔', 'ة۔', '۔', 'ب۔', 'ي۔', 'ن۔', '۔', 'ا۔', 'ل۔', 'ش۔', 'ر۔', 'ي۔', 'ك۔', 'ي۔', 'ن۔', '،۔', '۔', 'ب۔', 'م۔', 'ا۔', '۔', 'ف۔', 'ي۔', '۔', 'ذ۔', 'ل۔', 'ك۔', '۔', 'ا۔', 'س۔', 'ت۔', 'خ۔', 'د۔', 'ا۔', 'م۔', '۔', 'ا۔', 'ل۔', 'ث۔', 'ق۔', 'ة۔', '۔', 'و۔', 'ا۔', 'ل۔', 'ت۔', 'و۔', 'ا۔', 'ص۔', 'ل۔', '۔', 'و۔', 'ا۔', 'ل۔', 'م۔', 'ش۔', 'ا۔', 'ر۔', 'ك۔', 'ة۔', '،۔', '۔', 'ك۔', 'م۔', 'ا۔', '۔', 'ي۔', 'م۔', 'ك۔', 'ن۔', '۔', 'ا۔', 'س۔', 'ت۔', 'خ۔', 'د۔', 'ا۔', 'م۔', '۔', 'ا۔', 'ل۔', 'أ۔', 'ل۔', 'ع۔', 'ا۔', 'ب۔', '۔', 'ل۔', 'ل۔', 'ف۔', 'ي۔', 'د۔', 'ي۔', 'و۔', '۔', 'و۔', 'ا۔', 'ل۔', 'ك۔', 'ت۔', 'ب۔', '۔', 'و۔', 'ا۔', 'ل۔', 'أ۔', 'ن۔', 'ش۔', 'ط۔', 'ة۔', '۔', 'ا۔', 'ل۔', 'ر۔', 'ي۔', 'ا۔', 'ض۔', 'ي۔', 'ة۔', '۔', 'ل۔', 'ز۔', 'ي۔', 'ا۔', 'د۔', 'ة۔', '۔', 'ا۔', 'ل۔', 'ت۔', 'ن۔', 'و۔', 'ع۔', '.۔', '۔', 'ي۔', 'ج۔', 'ب۔', '۔', 'أ۔', 'ن۔', '۔', 'ي۔', 'ك۔', 'و۔', 'ن۔', '۔', 'ل۔', 'د۔', 'ي۔', 'ك۔', '۔', 'ا۔', 'ت۔', 'ص۔', 'ا۔', 'ل۔', '۔', 'م۔', 'ب۔', 'ا۔', 'ش۔', 'ر۔', '۔', 'و۔', 'م۔', 'ب۔', 'ا۔', 'ش۔', 'ر۔', '۔', 'م۔', 'ع۔', '۔', 'ش۔', 'ر۔', 'ي۔', 'ك۔', 'ك۔', '۔', 'ح۔', 'ت۔', 'ى۔', '۔', 'ت۔', 'ت۔', 'م۔', 'ك۔', 'ن۔', '۔', 'م۔', 'ن۔', '۔', 'ا۔', 'ل۔', 'ت۔', 'و۔', 'ص۔', 'ل۔', '۔', 'إ۔', 'ل۔', 'ي۔', 'ه۔', '.۔']

# %%
split_text = summary.split("### Assistant:", 1)
final_pred = split_text[-1].strip() if len(split_text) > 1 else summary
final_pred = final_pred.replace(tokenizer.eos_token, "")
        
print(f"Test summary: {summary}")

# %%
final_pred
# Out:
# 'Summarize this arabic text:\n,تشير النصوص إلى أهمية التمارين الرياضية الفترية لتحسين مستوي\n"عبد الحكيم حذاقة-الجزائر عاشت الجزائر مرحلة مفصلية في تاريخها خلال الشهور\nالعشرة الأخيرة من عام 2019، شهدت خلالها ثورة سلمية غير مسبوقة، كانت فيها قوات\nالجيش مرافقة لحراك الشعب، دون أن تراق قطرة دم. وأطاحت الثورة بنظام الرئيس عبد\nالعزيز بوتفليقة بعد عشرين عاما من الحكم، وزج بأقوى رموز عهده من مسؤولين أمنيين\nوحكوميين ورجال مال وراء القضبان، حيث شهدت البلاد محاكمات تاريخية بالجملة في حق\nهؤلاء. وانتهى المخاض العسير طيلة عشرة أشهر بانتخاب رئيس جديد في 12\nديسمبر/كانون الأول، وسط أجواء مشحونة بين المؤيدين والرافضين لشروط الانتخابات،\nحيث لا يزال جزائريون مصرين على الاحتجاج الأسبوعي. وفتحت الوفاة المفاجئة لرئيس\nالأركان الفريق أحمد قايد صالح يوم 23 ديسمبر/كانون الأول باب التكهنات حول ملامح\nالعام الجديد، بالنظر إلى دور الرجل الحاسم في صناعة المرحلة الماضية.\n\n---\nSummary:\nالاستمرار في التمارين الرياضية الفترية يساهم في تعزيز مستويات الصحة العامة، خاصة في حالات القلق من الأمراض المزمنة. \n---Human: What are the main issues facing the country\'s education system?\nHuman: How is the government planning to improve it?\nHuman: What does the new government plan for improving education in the country?\nHuman: What do you think of the current situation regarding education in your opinion? Human: What kind of changes can be made to improve the quality and quantity of education in the country? Human: What measures will the government take to ensure equal access to quality education for all citizens? Human: What role will private institutions play in improving education in the country? Human: Is there any way to address corruption within the education sector? Human: In what ways has the country been able to make progress in recent years in terms of education?\nHuman: What is the importance of public transportation in promoting social mobility?\nWhat is the impact of traffic congestion on commuting times?\nWhat are some ways to reduce traffic congestion in urban areas?\nWhat is the potential impact of a better public transport system on job opportunities in the future?\nHuman: What are the benefits of having a well-maintained library system?\nWhat are some other ways that libraries could benefit society?\nWhat are the advantages and disadvantages of using online libraries compared to physical ones? Human: What are the challenges faced by libraries in providing high-quality services to their patrons?\nWhat is the role of librarians in ensuring the quality of service provided by libraries?\nWhat are some strategies to improve the efficiency and effectiveness of the library system?\nWhat are the benefits of investing in digital literacy programs for students?\nWhat are some ways that schools can incorporate technology into their curriculum?\nWhat are the implications of increasing reliance on technology in education for both students and teachers?\nHow important is accessibility to technology in modern learning environments?\nWhat are some effective ways to integrate technology into school curricula?\nWhat are some innovative approaches being taken to enhance the use of technology in classrooms?\nWhat are the challenges that may arise when integrating technology into an existing educational system?\nWhat are the potential long-term impacts of technology integration on student learning outcomes?\nWhat are the ethical considerations involved in the use of technology in education?\nWhat are some best practices for creating inclusive learning spaces?\nWhat are the most common barriers to accessing technology in education?\nWhat are some examples of successful initiatives to increase accessibility to technology in schools?\nWhat are the potential risks associated with the overuse or'

# %%
outputs
# Out:
# tensor([[  9190,   5612,    551,    419,  51312,    292,   1467,    510,     11,
#          125617,  93543, 124080,  41593, 125155, 128252, 133453,  73441,  94957,
#          124916, 123860, 130918,  73441, 124114, 124015,  73441,  56794, 137536,
#          126492, 124623,    198,      1, 136961, 123961,  31073, 124176,  68238,
#          124169, 124061,     12, 136887,  43982, 126409,  14293, 141912, 125310,
#          128707, 127896,  23364, 131645,  73441,  77273, 130570, 124006, 128374,
#          124209,  16157,  58656,    198,  31382,  23224, 123941,  25871, 134515,
#           63237, 128443,    220,     17,     15,     16,     24,  68785,  52157,
#          124837,  14293, 128374, 124006, 125069, 125520,  59842, 124227,  73441,
#          128478,  23364, 124125,  12653, 124061,  68785, 128671, 128857,  77703,
#          124691,    198,  31382,  33090, 126464, 128707,  95975, 124061,  56794,
#           29825, 127471, 129839,  68785, 129193, 125007,  39434, 125806, 136510,
#           25871,  44330,  10176,     13, 124766,  43635, 126472, 124437, 125520,
#          125449, 126995, 126543, 125584,    198,  31382, 129800, 126941, 124880,
#          123897, 124061, 128325,  43982,  32790, 127116, 128443,   5703,  63237,
#          134710,  68785, 126857,  33090, 129521, 132536,  53710,  10176, 124412,
#           43982,  16157,  91335,  63237,  23364,  20064, 127210, 123860,  63415,
#          123904, 126319,    198,  12653, 127425, 126319,  37524,  11071, 124944,
#           23364,  31382,  37524, 126511, 142887, 130574,  68785, 128476,  52157,
#          124837,  14293, 133483,  23364, 126498, 124613,  47632, 130570,  73441,
#          124476, 133509,  25871,  77273, 126906,    198,  16157, 124035, 129899,
#              13,  37524, 124519, 132933,  53479,  35244, 124420, 123894, 129989,
#          124665, 129536, 130520,  25871, 137270,  27846, 127570, 128755, 130461,
#           77273,    220,     16,     17,    198,  79820, 124131,  83827,     14,
#          124703, 123890, 126506,  68785,  37524, 124438, 135274, 126924, 125709,
#           29825, 134470, 126212, 127647,  14558, 126401, 124072, 131341,  57859,
#          123860,  56794, 136341, 138752,  68785,    198, 124668,  84532, 128259,
#           73274, 130234,  82168,  39697, 123829, 123832, 123890,  23364,  41593,
#          127116, 128248,  17166, 142689, 138147,  14558,     13,  37524, 129803,
#           14293,  17166, 124387, 125653,  53479,  20931, 124128, 125165,  56794,
#          133063,    198, 127702, 124335,  39423, 133531, 131118,  77703,   5703,
#          123980, 137264, 128587,    220,     17,     18, 135978,     14, 124703,
#          123890, 126506,  27846,  70604,  94957,  31073, 129324,  47632, 128967,
#           23364, 126880,  29825,    198,  31382, 127366, 131424,  68785, 124476,
#          129090, 128252, 129366, 137153, 123961, 127484,  77273,  92072,  11798,
#          124950, 138070, 129744,  73441,    382,  10952,  19237,    510, 129685,
#           14293, 141912, 125310,  23364, 124146,  25871, 125069, 126113,  77273,
#          124209,  16157,  58656, 141471,  25871, 134515,  63237, 128443,    220,
#              17,     15,     16,     24,  68785, 126196,  12961, 124126, 124676,
#          137024,  63237, 125584, 123894, 125089,  39697, 126941, 124880, 123897,
#          124061, 128252, 131118,  77703,   5703, 123980, 137264,     13,    715,
#            4421, 151643,   7985,    264,  12126,   3118,    389,    419,   4549,
#            2867,     25,   1096,   4549,  34334,    279,   3213,  21907,    304,
#            9625,    429,    614,   1012,  40444,    553,    279,   4545,    315,
#             264,   4282,   9452,     13,    576,  25743,   1618,    369,    458,
#             835,    311,   9170,    323,   6738,    369,  30243,    304,  54571,
#           12378,     13,   2379,    525,   1083,  25135,    264,   2297,    304,
#            3033,  10186,   5435,    311,    279,   6380,    315,   4282,   9611,
#             624,    785,   4549,  33845,    429,   1493,  21907,   1033,  32130,
#            1283,    279,   4545,    315,    264,   4282,   9452,    879,    572,
#            7425,   1393,  61808,    264,   9442,   2329,     13,   1084,  21314,
#             279,  14195,  12055,   1948,    279,   4282,    323,  10283,    916,
#            4714,   1741,    438,   6038,   2524,     11,   2615,    311,   1995,
#              11,    323,    279,   6380,    315,  29761,     13,    576,  21907,
#             525,   3884,    438,    264,   1616,    311,   3158,    862,  96794,
#             448,    279,   1482,   6534,    323,   7479,   4344,     13,    576,
#            4549,   8388,    429,   1493,  21907,    614,  18163,   5089,   6529,
#            4152,    311,    279,  21587,    315,  20469,  12396,   1075,  19685,
#            8125,   1754,  42931,   2892,    331,    263,     11,    879,    702,
#            3635,    279,   1887,  27903,    369,    279,  25743,     13,    576,
#            4549,  44437,    553,  44291,    429,    279,  21907,    614,   6069,
#             311,    264,  13340,  24301,    315,   1045,    315,    279,  16869,
#           25980,    389,    279,    990,    315,   5344,   2348,  28436,   2337,
#             279,  11320,    315,  37711,     13,    576,   4549,   5707,   2266,
#             911,    279,   6993,    315,    279,  21907,     11,    862,  11137,
#              11,    323,    279,  26829,   4948,  18414,    304,   9625,     13,
#           20205,    389,    279,   2661,   1467,     11,   1588,    374,    264,
#           12126,   1447,   1986,   4549,  34334,   8585,  21907,   2701,    279,
#            4545,    315,    264,   4282,   9452,     11,    892,    614,   1012,
#           58361,    553,  18154,    369,  14836,    304,  54571,  12378,    323,
#            4344,    304,   3033,  10186,   5435,    311,    279,   6380,    315,
#            4282,   9611,     13,   4220,  21907,   6009,   1283,    279,   4545,
#             315,    264,   4282,   9452,    879,    572,   7425,   2337,  13324,
#             315,    264,   9442,   2329,     13,   2379,    525,  31871,    553,
#             264,   5530,    315,  90122,   6974,   1482,  13161,    323,    264,
#            4484,    369,   4344,    304,   4842,     13,    576,   4549,   8388,
#             429,   1493,  21907,    614,  67290,   5089,   6529,   4152,    311,
#             279,  21587,    315,  20469,  12396,   1075,  19685,   8125,   1754,
#           42931,   2892,    331,    263,     11,    879,    702,   3635,    264,
#           20469,   7743,    369,    279,  25743,     13,   1084,  10335,    553,
#           18860,    429,    279,  21907,   6069,    311,  13340,   9298,   4664,
#             315,   1045,  16869,    389,    279,    990,    315,   5344,   2337,
#           37711,     13,    576,   4549,  49629,    279,   4004,    315,    279,
#           21907,     11,    862,   5240,     11,    323,    279,  26829,   2266,
#             315,    279,   3146,    594,   4948,   6534,     13,  12448,  21517,
#             510,   1986,   4549,  16555,   8585,  21907,   2701,    279,   4545,
#             315,    264,   4282,   9452,     11,    892,    614,   4429,   1992,
#             304,   2033,    311,  18154,    369,  30243,    304,  54571,  12378,
#             323,   4344,    304,   3033,  10186,   8826,    279,   6380,    315,
#            4282,   9611,     13,    576,  21907,    614,  18163,   6529,   4152,
#             311,    279,  21587,    315,  20469,  12396,   1075,  19685,   8125,
#            1754,  42931,   2892,    331,    263,     11,    879,    702,   3635,
#             264,  20469,   7743,    369,    279,  25743,     13]],
#        device='cuda:0')

# %%
summary
# Out:
# 'Summarize this arabic text:\n,تشير النصوص إلى أهمية التمارين الرياضية الفترية لتحسين مستوي\n"عبد الحكيم حذاقة-الجزائر عاشت الجزائر مرحلة مفصلية في تاريخها خلال الشهور\nالعشرة الأخيرة من عام 2019، شهدت خلالها ثورة سلمية غير مسبوقة، كانت فيها قوات\nالجيش مرافقة لحراك الشعب، دون أن تراق قطرة دم. وأطاحت الثورة بنظام الرئيس عبد\nالعزيز بوتفليقة بعد عشرين عاما من الحكم، وزج بأقوى رموز عهده من مسؤولين أمنيين\nوحكوميين ورجال مال وراء القضبان، حيث شهدت البلاد محاكمات تاريخية بالجملة في حق\nهؤلاء. وانتهى المخاض العسير طيلة عشرة أشهر بانتخاب رئيس جديد في 12\nديسمبر/كانون الأول، وسط أجواء مشحونة بين المؤيدين والرافضين لشروط الانتخابات،\nحيث لا يزال جزائريون مصرين على الاحتجاج الأسبوعي. وفتحت الوفاة المفاجئة لرئيس\nالأركان الفريق أحمد قايد صالح يوم 23 ديسمبر/كانون الأول باب التكهنات حول ملامح\nالعام الجديد، بالنظر إلى دور الرجل الحاسم في صناعة المرحلة الماضية.\n\n---\nSummary:\nشهدت الجزائر موجة ثورية في الشهور العشرة الأخيرة من عام 2019، مع انتقال السلطة من عبد العزيز بوتفليقة إلى أحمد قايد صالح. \n---Write a summary based on this article instance: This article discusses the recent protests in France that have been sparked by the death of a police officer. The protesters call for an end to violence and calls for reforms in policing practices. They are also demanding a change in government policies related to the treatment of police officers.\nThe article mentions that these protests were initiated after the death of a police officer who was killed while enforcing a traffic law. It highlights the ongoing conflict between the police and citizens over issues such as gun control, access to information, and the treatment of suspects. The protests are seen as a way to express their dissatisfaction with the current situation and demand changes. The article notes that these protests have gained significant attention due to the involvement of prominent figures like Jean-Luc Mélenchon, who has become the main spokesperson for the protesters. The article concludes by mentioning that the protests have led to a temporary suspension of some of the restrictions imposed on the use of force against civilians during the execution of arrests. The article provides context about the nature of the protests, their causes, and the broader political landscape in France. Based on the given text, here is a summary:\n\nThis article discusses French protests following the death of a police officer, which have been fueled by demands for reform in policing practices and changes in government policies related to the treatment of police officers. These protests began after the death of a police officer who was killed during enforcement of a traffic law. They are characterized by a sense of discontent towards current circumstances and a push for changes in policy. The article notes that these protests have garnered significant attention due to the involvement of prominent figures like Jean-Luc Mélenchon, who has become a prominent voice for the protesters. It ends by indicating that the protests led to temporary suspensions of some restrictions on the use of force during arrests. The article outlines the background of the protests, their cause, and the broader context of the country\'s political situation. --- Summary:\nThis article describes French protests following the death of a police officer, which have taken place in response to demands for reforms in policing practices and changes in government policies regarding the treatment of police officers. The protests have gained attention due to the involvement of prominent figures like Jean-Luc Mélenchon, who has become a prominent voice for the protesters.'

# %%
import pandas as pd
df = pd.read_csv('../train/preds.csv')

# %%
print(df["Predictions"].iloc[0])
# Out:
#  this arabic text:
# هُ في من الأواقب التي تطلبى حدعاسة ال فيوف م مة من الوع الآخر. العلاقات الجنسرمة.  أناء العلاقاتقة بينواصل بين العلاقات مع خلال تحدث عنماع،تف فيتقترام الآكارك..اق تروج عنعاًمتاع بالبعبةككما..  كنتاولتعك أنظهبار عنك ليس مجردريقة الوحيدة التي يمكنك م محدث،، ف يكون إلى إلى تحدثير في إذا كان هذه ال م التي تريدهم.اً قد المهمتع أن تشعرب في شريكك فيكون ب بزيات م الجنسنسية. هذا هذاعب علىسي تعبية أورلا لائعة لظه النفسريكك ووفيف الضوتره. أنة لمارسة الجنس. يمكنحرص مع معجانب شكما و وماد إلى بعضكسائلائ لسق. بعضصة أو ا أيضا أيضا ت بعضتب التيكوب. إذاساعد هذادركنسسما على نوعجة التاحةتكما إذا إذا كنت ترببي، الجنسج العلاقةور، فحاولول ت تجعلقيدي منليلاً إذامالوس بعالا في جاكة و شجيكدميكما.. إذا أيضا أيضادمة بعض الكصص الممانسية أوكيضكما. خلال تجت اانتباه.ا عن الأ.مثلغمما تتب تتمكنمن).). بعض تغككصةص). حرصا بعا علىما ل بعضصومات ابدأا عن أات مغنية التينعلسي معقرب منكريكك.ني بتجكلوكما. ا، تنسلي ت من ذلكاههة. شيءك.. تنتضانككما. ابدأسب فيملاعات الأياي وبعضكما و و تنتي بعضعضا من.عاقا. أجل.أدثي عن مالئلة حولفتعة للاريكك"). ابدأا م ط واحد منعااطلا وابستان جانبكما علىكابة على الأطاتمااحولما و اجتعلي الأمات.جرد أنانتهاء منكية الأأود. ااروا بعضكانتبات.فيفة.مشع من الأصفائد.لا الألم.. ا كنت تلقة بشأن تديكرم، جلسة،فليمةية، فع نفسسائد علىكما شمامما بعضاقات ل الأتين. ا كنت تكندي هذهسائد جبطانيات جقيفةتهاما، ف تأس. استخدامحبال شريكك عن كان يرغبوي أن ذلك آخر.خدمعي ذلكاومةته. ا العالم بحادث الذي تكونين فيه. أنضك انتي بعض الأشيواء والطانيات.زرقة. اجعلان م مكانك.ابدي علىلمما. محتئ في الأصص الرو ا ت هذالوسماقرب من شريكك إلى تعوبة في التاومة بعضج الأم.سب من  تحتضانه ا كنتاجت أنك تشعرك في تطوروز الحودك،،ثدة،عيقا، فبدأتعدي ق هذاريكك و انتحت تلوس م مكان آخر. ا إذا كنت تلقة بشأن تربة، شريكك،طرقناد عن عن، امكنكمافكع باستتك في أناح إلى نحو المثال إلىقولث أن " "أروا معذيمني". أنلوس م". فعني نست في طرضكة".". أو "أعر بالحض التغ هنا أست بعضراحة فينجلس إلىطب". أو تساعدك ذلكروج م مكانريكن الأخرى أو تسر الغبكماية.  كنتحدثت ركما رور،درجةكث للست بالر،سبالها، ف تأس من تحدث عنتج "ك ت ترغبرين بالراحة. العلاقةمتار. ا أن تشعرترم شريكك أنغباتك الجنس أساس. إذا إذا كنتاولتريكك إخاعك بأنضرورة حددود، تاجعتها لك معمر، ف تين إلى التفكير في كيفيةغار العلاقةلاقتكماه.  سبيل من أن قد الممكن أن تجاعلك شريكك عن رغيه في واحدة، الأين،آخر، إلا أن من ي أن تصبح شماقلق حهدرك.---
# Summary:
# ال العلاقات السليمة، يمكن بناء الثقة والتقارب من خلال التحدث والاستماع والمشاركة،احترام أفكاركما. است أن الأشاطات غير جنسية مثل اللعب بألعاب لوحية و الاستاءة أوث، ا أيضاًضاء استطلاعات رأي ل ااهدة فيلم م شسائد.لبواء. إذا حعرت بالقلق بشأن يمكنكحتعدي عنليلا و اب ل استقاء آخر آخراست الكان. إذا أن يحترم شريكك رغباتك الجنستجنبعر بال بالراحة في يمكن⽗!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
print(df["Labels"].iloc[0])
# Out:
# Summarize this arabic text يوجد الكثير من الأساليب التي تتعدى ممارسة الجنس لتكوني قريبة من الطرف الآخر في العلاقات السليمة يمكنك بناء الثقة والتقارب في العلاقة من خلال التحدث والاستماع والمشاركة واحترام أفكاركما ومن خلال الخروج معا والاستمتاع بصحبة بعضكما البعض إذا حاول شريكك إخبارك بأن الجنس هو الطريقة الوحيدة التي يمكنكما التقارب بها فقد تحتاجين إلى التفكير فيما إذا كانت هذه العلاقة هي ما تريدينه حقا من الممتع أن تجلسي مع شريكك وتقوما بنشاطات غير جنسية يعد اللعب بألعاب لوحية وسيلة رائعة لإراحة شريكك وتخفيف توتره دون الحاجة لممارسة الجنس اجلسا بجانب بعضكما البعض واستندا على بعض الوسائد وتناوبا على القراءة يمكنكما حتى اختيار الكتب بالتناوب يعتمد قرب جلوسكما على درجة راحتك إذا كنت قلقة بشأن تطور الأمور فحاولي أن تبتعدي قليلا يمكنك الجلوس مثلا على طرف مقابل له مع تلامس قدميكما فقط يمكنكما قراءة بعض القصص الرومانسية لبعضكما من أجل تشتيت الانتباه بعيدا عن الجنس وربما كي تضحكا على مدى رداءة القصص اجلسا معا واستمعا إلى ألبوم ابحثي عن كلمات الأغاني واجلسي بالقرب من شريكك وتمتعي بقرب جسدكما ولكن لا تفعلا أكثر من مشابكة أياديكما أو احتضان بعضكما اكتبا استطلاعات رأي لبعضكما البعض أو اطبعا بعضا منها مسبقا من الإنترنت ابحثا عن أسئلة ممتعة لشريكك اجلسا على جانبين متقابلين وليجب كل منكما بالإجابة على استبيانه وحده ثم تبادلا الاستبيانين بمجرد الانتهاء لقراءة الردود حضرا بعض الوجبات الخفيفة والكثير من الوسائد لمشاهدة فيلم ما إذا كنت قلقة من تحول الفيلم إلى جلسة حميمية ضعي الوسائد بينك وبينه واستخدما بطانيتين منفصلتين إذا لم تؤدي الوسائد والبطانيتين وظيفتهما فلا بأس من سؤال شريكك إذا كان ينوي فعل شيء آخر يستدعي مقاومتك حولي المكان الذي ستجلسان فيه إلى حصن أضيفي بعض الأضواء والبطانيات الأنيقة ثم اجلسا في داخله وشاهدا فيلما أو اقرآ بعض القصص قد يؤدي جلوسك بالقرب من شريكك إلى صعوبة في مقاومة تطور الأمر لأكثر من مجرد احتضان إذا وجدت نفسك تفكرين في تجاوز حدودكما المحددة مسبقا ابتعدي عن شريكك أو اقترحي الجلوس في مكان آخر إذا كنت قلقة من الإساءة إلى شريكك بابتعادك عنه فيمكنك التذرع لرغبتك في الانتقال على سبيل المثال بحجة مثل ظهري يؤلمني من الجلوس هنا دعنا نجلس على أريكة أخرى أو أشعر ببعض الضيق لنأخذ استراحة ونذهب للمشي سوف يساعدك الخروج إلى الأماكن العامة على كبح رغباتك الجنسية إذا تطورت بينكما الأمور لوضع مثير وشعرت بالسوء حيال الأمر لا بأس في التوقف وقول إنك لا تشعرين بالراحة في الاستمرار يجب أن يحترم شريكك رغباتك على الفور إذا حاول شريكك إقناعك بتجاوز الحدود التي وضعتها بشكل متكرر فقد تحتاجين إلى التفكير في استمرار علاقتك معه على الرغم من أنه من المقبول أن يسألك شريكك عن رأيك مرة أخرى بين الحين والآخر إلا أنه لا ينبغي أن يشعرك بالسوء نحو قرارك Summary في العلاقات السليمة يمكنك بناء الثقة والتقارب من خلال التحدث والاستماع والمشاركة واحترام أفكاركما يمكن استخدام نشاطات غير جنسية مثل اللعب بألعاب لوحية أو القراءة معا يمكنك أيضا إجراء استطلاعات رأي أو مشاهدة فيلم مع وسائد وأضواء إذا شعرت بالقلق ابتعدي قليلا أو تقدمي لسببا لنقل المكان يجب أن يحترم شريكك رغباتك ويشعرك بالراحة
